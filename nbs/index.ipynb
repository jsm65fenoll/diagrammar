# %%
#| hide
from diagrammar.core import *

# %% [markdown]
# # diagrammar
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install diagrammar in Development mode

# %% [markdown]
# ```sh
# # make sure diagrammar package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to diagrammar
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/jsm65fenoll/diagrammar.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c jsm65fenoll diagrammar
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install diagrammar
# ```
#
#
# [repo]: https://github.com/jsm65fenoll/diagrammar
# [docs]: https://jsm65fenoll.github.io/diagrammar/
# [pypi]: https://pypi.org/project/diagrammar/
# [conda]: https://anaconda.org/jsm65fenoll/diagrammar

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/jsm65fenoll/diagrammar
# [docs]: https://jsm65fenoll.github.io/diagrammar/
# [pypi]: https://pypi.org/project/diagrammar/
# [conda]: https://anaconda.org/jsm65fenoll/diagrammar

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
